# %%
# Notes on memory usage: On my computer, it took 5 minutes to run 2 months (Jan 1st to March 1st 2017)

# %%
from main import main

# %%
from dask.distributed import Client, LocalCluster
cluster = LocalCluster()
client = Client(cluster)
client
# Out:
# <Client: 'tcp://127.0.0.1:33251' processes=4 threads=16, memory=7.64 GiB>

# %%
bbox = (32.16033157094111, 22.852984440390316, 33.288140399555346, 23.806193394664234)
start_date = "2017-01-01"
end_date = "2017-03-01"

# %%
# %time main(bbox, start_date, end_date)
# Out:
# /opt/conda/envs/assignment-6/lib/python3.13/site-packages/dask/core.py:133: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /opt/conda/envs/assignment-6/lib/python3.13/site-packages/dask/core.py:133: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /opt/conda/envs/assignment-6/lib/python3.13/site-packages/dask/core.py:133: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /opt/conda/envs/assignment-6/lib/python3.13/site-packages/dask/core.py:133: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# CPU times: user 1min 7s, sys: 6.98 s, total: 1min 14s
# Wall time: 5min 29s
